# %% [markdown]
# # Problem Statement
#
# This notebook explores two different collaborative filtering mechanism:
# 1. User-User collaborative filtering
# 2. Item-Item collaborative filtering

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import pairwise_distances
from sklearn.model_selection import train_test_split
import pickle

# %%
df = pd.read_csv("sample30.csv")
df.head()
# Out:
#                      id            brand  \
# 0  AV13O1A8GV-KLJ3akUyj  Universal Music
# 1  AV14LG0R-jtxr-f38QfS         Lundberg
# 2  AV14LG0R-jtxr-f38QfS         Lundberg
# 3  AV16khLE-jtxr-f38VFn              K-Y
# 4  AV16khLE-jtxr-f38VFn              K-Y
#
#                                           categories  \
# 0  Movies, Music & Books,Music,R&b,Movies & TV,Mo...
# 1  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...
# 2  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...
# 3  Personal Care,Medicine Cabinet,Lubricant/Sperm...
# 4  Personal Care,Medicine Cabinet,Lubricant/Sperm...
#
#                          manufacturer  \
# 0  Universal Music Group / Cash Money
# 1                            Lundberg
# 2                            Lundberg
# 3                                 K-Y
# 4                                 K-Y
#
#                                          name              reviews_date  \
# 0   Pink Friday: Roman Reloaded Re-Up (w/dvd)  2012-11-30T06:21:45.000Z
# 1  Lundberg Organic Cinnamon Toast Rice Cakes  2017-07-09T00:00:00.000Z
# 2  Lundberg Organic Cinnamon Toast Rice Cakes  2017-07-09T00:00:00.000Z
# 3            K-Y Love Sensuality Pleasure Gel  2016-01-06T00:00:00.000Z
# 4            K-Y Love Sensuality Pleasure Gel  2016-12-21T00:00:00.000Z
#
#   reviews_didPurchase reviews_doRecommend  reviews_rating  \
# 0                 NaN                 NaN               5
# 1                True                 NaN               5
# 2                True                 NaN               5
# 3               False               False               1
# 4               False               False               1
#
#                                         reviews_text reviews_title  \
# 0  i love this album. it's very good. more to the...  Just Awesome
# 1  Good flavor. This review was collected as part...          Good
# 2                                       Good flavor.          Good
# 3  I read through the reviews on here before look...  Disappointed
# 4  My husband bought this gel for us. The gel cau...    Irritation
#
#   reviews_userCity reviews_userProvince reviews_username user_sentiment
# 0      Los Angeles                  NaN           joshua       Positive
# 1              NaN                  NaN        dorothy w       Positive
# 2              NaN                  NaN        dorothy w       Positive
# 3              NaN                  NaN          rebecca       Negative
# 4              NaN                  NaN        walker557       Negative

# %%
# removing duplicates
df =df.dropna(axis=0,subset=['reviews_username','reviews_rating'])
df=df.drop_duplicates(subset=['reviews_username'])

# %%
df['reviews_rating']=df['reviews_rating'].astype(float)

# %%
train,test = train_test_split(df,test_size=0.3,random_state=42)

# %%
train.head()
# Out:
#                          id                 brand  \
# 14499  AVpf3VOfilAPnD_xjpun                Clorox
# 16857  AVpf9pzn1cnluZ0-uNTM              Lundberg
# 15730  AVpf5Z1zLJeJML43FpB-                 Lysol
# 27135  AVpfRoqcLJeJML436FqG                 Vicks
# 2704   AVpe59io1cnluZ0-ZgDU  Universal Home Video
#
#                                               categories  \
# 14499  Household Essentials,Cleaning Supplies,Kitchen...
# 16857  Food,Packaged Foods,Packaged Grains,Rice,Brown...
# 15730  Household Chemicals,Household Cleaners,Disinfe...
# 27135  Personal Care,Medicine Cabinet,Cough/Cold,Heal...
# 2704   Movies, Music & Books,Movies,Comedy,Movies & T...
#
#                 manufacturer  \
# 14499                 Clorox
# 16857  Lundberg Family Farms
# 15730      Reckitt Benckiser
# 27135                    P&G
# 2704               Universal
#
#                                                     name  \
# 14499  Clorox Disinfecting Wipes Value Pack Scented 1...
# 16857                         Lundberg Wehani Rice, 25lb
# 15730  Lysol Concentrate Deodorizing Cleaner, Origina...
# 27135                     Vicks Vaporub, Regular, 3.53oz
# 2704   My Big Fat Greek Wedding 2 (blu-Ray + Dvd + Di...
#
#                    reviews_date reviews_didPurchase reviews_doRecommend  \
# 14499  2014-12-04T00:00:00.000Z               False                True
# 16857  2017-03-28T00:00:00.000Z                 NaN                 NaN
# 15730  2012-05-02T00:00:00.000Z               False                True
# 27135  2017-04-01T00:00:00.000Z               False               False
# 2704   2016-08-06T00:00:00.000Z                 NaN                True
#
#        reviews_rating                                       reviews_text  \
# 14499             5.0  this clorox wipe cleans good. it can wipe ever...
# 16857             5.0                                      fabulous item
# 15730             5.0  clean with this in bathrooms, kitchen, and was...
# 27135             1.0  I purchased this and realized upon opening tha...
# 2704              4.0  Its not as good as 1 st, but still enjoyed it....
#
#              reviews_title reviews_userCity reviews_userProvince  \
# 14499                 good              NaN                  NaN
# 16857           Five Stars              NaN                  NaN
# 15730  product is the best              NaN                  NaN
# 27135  Jar was not sealed.              NaN                  NaN
# 2704                  Cute              NaN                  NaN
#
#        reviews_username user_sentiment
# 14499        lilxkrnxqt       Positive
# 16857  byjean l'heureux       Positive
# 15730            grammy       Positive
# 27135   phantompunk1317       Negative
# 2704             trisha       Positive

# %% [markdown]
# ## User-User colloborative filtering

# %%
# Creating a pivot table
df_pivot = train.pivot(
    index='reviews_username',
    columns='id',
    values='reviews_rating'
).fillna(0)

df_pivot.head(3)
# Out:
# id                AV13O1A8GV-KLJ3akUyj  AV14LG0R-jtxr-f38QfS  \
# reviews_username
# 00dog3                             0.0                   0.0
# 01impala                           0.0                   0.0
# 02dakota                           0.0                   0.0
#
# id                AV16khLE-jtxr-f38VFn  AV1YGDqsGV-KLJ3adc-O  \
# reviews_username
# 00dog3                             0.0                   0.0
# 01impala                           0.0                   0.0
# 02dakota                           0.0                   0.0
#
# id                AV1YIch7GV-KLJ3addeG  AV1YlENIglJLPUi8IHsX  \
# reviews_username
# 00dog3                             0.0                   0.0
# 01impala                           0.0                   0.0
# 02dakota                           0.0                   0.0
#
# id                AV1YmBrdGV-KLJ3adewb  AV1YmDL9vKc47QAVgr7_  \
# reviews_username
# 00dog3                             0.0                   0.0
# 01impala                           0.0                   0.0
# 02dakota                           0.0                   0.0
#
# id                AV1Ymf_rglJLPUi8II2v  AV1Yn94nvKc47QAVgtst  ...  \
# reviews_username                                              ...
# 00dog3                             0.0                   0.0  ...
# 01impala                           0.0                   0.0  ...
# 02dakota                           0.0                   0.0  ...
#
# id                AVpfpoUCLJeJML43BLXv  AVpfqW4WilAPnD_xf7a_  \
# reviews_username
# 00dog3                             0.0                   0.0
# 01impala                           0.0                   0.0
# 02dakota                           0.0                   0.0
#
# id                AVpfr5cb1cnluZ0-pZFp  AVpfrFDZLJeJML43Bmv0  \
# reviews_username
# 00dog3                             0.0                   0.0
# 01impala                           0.0                   0.0
# 02dakota                           0.0                   0.0
#
# id                AVpfrTyiLJeJML43BrSI  AVpfrfHF1cnluZ0-pRai  \
# reviews_username
# 00dog3                             0.0                   0.0
# 01impala                           0.0                   0.0
# 02dakota                           0.0                   0.0
#
# id                AVpfrgjFLJeJML43BvCc  AVpfthSailAPnD_xg3ON  \
# reviews_username
# 00dog3                             0.0                   0.0
# 01impala                           0.0                   0.0
# 02dakota                           0.0                   0.0
#
# id                AVpftikC1cnluZ0-p31V  AVpfvieo1cnluZ0-qdnu
# reviews_username
# 00dog3                             0.0                   0.0
# 01impala                           0.0                   0.0
# 02dakota                           0.0                   0.0
#
# [3 rows x 246 columns]

# %%
# normalizing the pivot table by subtracting from the mean
mean = np.nanmean(df_pivot,axis=1)
mean.shape
# Out:
# (17439,)

# %%
# normalizing the pivot table as most of users have not rated
df_subtracted=df_pivot-mean[:,None]

# %%
df_subtracted
# Out:
# id                AV13O1A8GV-KLJ3akUyj  AV14LG0R-jtxr-f38QfS  \
# reviews_username
# 00dog3                       -0.016260             -0.016260
# 01impala                     -0.012195             -0.012195
# 02dakota                     -0.020325             -0.020325
# 02deuce                      -0.016260             -0.016260
# 0325home                     -0.020325             -0.020325
# ...                                ...                   ...
# zxcsdfd                      -0.020325             -0.020325
# zxjki                        -0.008130             -0.008130
# zyiah4                       -0.020325             -0.020325
# zzdiane                      -0.020325             -0.020325
# zzz1127                      -0.016260             -0.016260
#
# id                AV16khLE-jtxr-f38VFn  AV1YGDqsGV-KLJ3adc-O  \
# reviews_username
# 00dog3                       -0.016260             -0.016260
# 01impala                     -0.012195             -0.012195
# 02dakota                     -0.020325             -0.020325
# 02deuce                      -0.016260             -0.016260
# 0325home                     -0.020325             -0.020325
# ...                                ...                   ...
# zxcsdfd                      -0.020325             -0.020325
# zxjki                        -0.008130             -0.008130
# zyiah4                       -0.020325             -0.020325
# zzdiane                      -0.020325             -0.020325
# zzz1127                      -0.016260             -0.016260
#
# id                AV1YIch7GV-KLJ3addeG  AV1YlENIglJLPUi8IHsX  \
# reviews_username
# 00dog3                       -0.016260             -0.016260
# 01impala                     -0.012195             -0.012195
# 02dakota                     -0.020325             -0.020325
# 02deuce                      -0.016260             -0.016260
# 0325home                     -0.020325             -0.020325
# ...                                ...                   ...
# zxcsdfd                      -0.020325             -0.020325
# zxjki                        -0.008130             -0.008130
# zyiah4                       -0.020325             -0.020325
# zzdiane                      -0.020325             -0.020325
# zzz1127                      -0.016260             -0.016260
#
# id                AV1YmBrdGV-KLJ3adewb  AV1YmDL9vKc47QAVgr7_  \
# reviews_username
# 00dog3                       -0.016260             -0.016260
# 01impala                     -0.012195             -0.012195
# 02dakota                     -0.020325             -0.020325
# 02deuce                      -0.016260             -0.016260
# 0325home                     -0.020325             -0.020325
# ...                                ...                   ...
# zxcsdfd                      -0.020325             -0.020325
# zxjki                        -0.008130             -0.008130
# 0325home                     -0.020325             -0.020325
# ...                                ...                   ...
# zxcsdfd                      -0.020325             -0.020325
# zxjki                        -0.008130             -0.008130
# zyiah4                       -0.020325             -0.020325
# zzdiane                      -0.020325             -0.020325
# zzz1127                      -0.016260             -0.016260
#
# [17439 rows x 246 columns]

# %%
# finding user correlation using cosine similarity
user_correlation =1- (pairwise_distances(df_subtracted.fillna(0),metric='cosine'))
#user_correlation[np.isnan(user_correlation)]=0
user_correlation.shape
# Out:
# (17439, 17439)

# %%
user_correlation
# Out:
# array([[ 1.        , -0.00408163, -0.00408163, ..., -0.00408163,
#         -0.00408163, -0.00408163],
#        [-0.00408163,  1.        ,  1.        , ..., -0.00408163,
#         -0.00408163, -0.00408163],
#        [-0.00408163,  1.        ,  1.        , ..., -0.00408163,
#         -0.00408163, -0.00408163],
#        ...,
#        [-0.00408163, -0.00408163, -0.00408163, ...,  1.        ,
#         -0.00408163,  1.        ],
#        [-0.00408163, -0.00408163, -0.00408163, ..., -0.00408163,
#          1.        , -0.00408163],
#        [-0.00408163, -0.00408163, -0.00408163, ...,  1.        ,
#         -0.00408163,  1.        ]])

# %%
# to predict the ratings we need to create a dummy train where 1 is assigned to rating not given by user
dummy_train = train.copy()
dummy_train['reviews_rating'] = dummy_train['reviews_rating'].apply(lambda x:0 if x>=1 else 1)

# %%
dummy_train = dummy_train.pivot(index='reviews_username',columns='id',values='reviews_rating').fillna(1)
dummy_train.head()
# Out:
# id                AV13O1A8GV-KLJ3akUyj  AV14LG0R-jtxr-f38QfS  \
# reviews_username
# 00dog3                             1.0                   1.0
# 01impala                           1.0                   1.0
# 02dakota                           1.0                   1.0
# 02deuce                            1.0                   1.0
# 0325home                           1.0                   1.0
#
# id                AV16khLE-jtxr-f38VFn  AV1YGDqsGV-KLJ3adc-O  \
# reviews_username
# 00dog3                             1.0                   1.0
# 01impala                           1.0                   1.0
# 02dakota                           1.0                   1.0
# 02deuce                            1.0                   1.0
# 0325home                           1.0                   1.0
#
# id                AV1YIch7GV-KLJ3addeG  AV1YlENIglJLPUi8IHsX  \
# reviews_username
# 00dog3                             1.0                   1.0
# 01impala                           1.0                   1.0
# 02dakota                           1.0                   1.0
# 02deuce                            1.0                   1.0
# 0325home                           1.0                   1.0
#
# id                AV1YmBrdGV-KLJ3adewb  AV1YmDL9vKc47QAVgr7_  \
# reviews_username
# 00dog3                             1.0                   1.0
# 01impala                           1.0                   1.0
# 02dakota                           1.0                   1.0
# 02deuce                            1.0                   1.0
# 0325home                           1.0                   1.0
#
# id                AV1Ymf_rglJLPUi8II2v  AV1Yn94nvKc47QAVgtst  ...  \
# reviews_username                                              ...
# 00dog3                             1.0                   1.0  ...
# 01impala                           1.0                   1.0  ...
# 02dakota                           1.0                   1.0  ...
# 02deuce                            1.0                   1.0  ...
# 0325home                           1.0                   1.0  ...
#
# id                AVpfpoUCLJeJML43BLXv  AVpfqW4WilAPnD_xf7a_  \
# reviews_username
# 00dog3                             1.0                   1.0
# 01impala                           1.0                   1.0
# 02dakota                           1.0                   1.0
# 02deuce                            1.0                   1.0
# 0325home                           1.0                   1.0
#
# id                AVpfr5cb1cnluZ0-pZFp  AVpfrFDZLJeJML43Bmv0  \
# reviews_username
# 00dog3                             1.0                   1.0
# 01impala                           1.0                   1.0
# 02dakota                           1.0                   1.0
# 02deuce                            1.0                   1.0
# 0325home                           1.0                   1.0
#
# id                AVpfrTyiLJeJML43BrSI  AVpfrfHF1cnluZ0-pRai  \
# reviews_username
# 00dog3                             1.0                   1.0
# 01impala                           1.0                   1.0
# 02dakota                           1.0                   1.0
# 02deuce                            1.0                   1.0
# 0325home                           1.0                   1.0
#
# id                AVpfrgjFLJeJML43BvCc  AVpfthSailAPnD_xg3ON  \
# reviews_username
# 00dog3                             1.0                   1.0
# 01impala                           1.0                   1.0
# 02dakota                           1.0                   1.0
# 02deuce                            1.0                   1.0
# 0325home                           1.0                   1.0
#
# id                AVpftikC1cnluZ0-p31V  AVpfvieo1cnluZ0-qdnu
# reviews_username
# 00dog3                             1.0                   1.0
# 01impala                           1.0                   1.0
# 02dakota                           1.0                   1.0
# 02deuce                            1.0                   1.0
# 0325home                           1.0                   1.0
#
# [5 rows x 246 columns]

# %%
# predict user rating  - dot product of user correlation and pivot table
user_predicted_ratings = np.dot(user_correlation,df_subtracted.fillna(0))

# %%
# final ratings
final_ratings = np.multiply(user_predicted_ratings,dummy_train)

# %%
final_ratings
# Out:
# id                AV13O1A8GV-KLJ3akUyj  AV14LG0R-jtxr-f38QfS  \
# reviews_username
# 00dog3                        1.025452              1.025452
# 01impala                    -34.288834            -34.288834
# 02dakota                    -34.288834            -34.288834
# 02deuce                     -34.288834            -34.288834
# 0325home                   -104.362303           -104.362303
# ...                                ...                   ...
# zxcsdfd                    -104.362303           -104.362303
# zxjki                      -104.362303           -104.362303
# zyiah4                     -104.362303           -104.362303
# zzdiane                      -5.815364             -5.815364
# zzz1127                    -104.362303           -104.362303
#
# id                AV16khLE-jtxr-f38VFn  AV1YGDqsGV-KLJ3adc-O  \
# reviews_username
# 00dog3                        0.792799             -2.929650
# 01impala                    -34.521487            -38.243936
# 02dakota                    -34.521487            -38.243936
# 02deuce                     -34.521487            -38.243936
# 0325home                   -104.594956           -108.317405
# ...                                ...                   ...
# zxcsdfd                    -104.594956           -108.317405
# zxjki                      -104.594956           -108.317405
# zyiah4                     -104.594956           -108.317405
# zzdiane                      -6.048017             -9.770466
# zzz1127                    -104.594956           -108.317405
#
# id                AV1YIch7GV-KLJ3addeG  AV1YlENIglJLPUi8IHsX  \
# reviews_username
# 00dog3                        1.025452              0.841779
# 01impala                    -34.288834            -34.472507
# 02dakota                    -34.288834            -34.472507
# 02deuce                     -34.288834            -34.472507
# 0325home                   -104.362303           -104.545976
# ...                                ...                   ...
# zxcsdfd                    -104.362303           -104.545976
# zxjki                      -104.362303           -104.545976
# zyiah4                     -104.362303           -104.545976
# zzdiane                      -5.815364             -5.999038
# zzz1127                    -104.362303           -104.545976
#
# id                AV1YmBrdGV-KLJ3adewb  AV1YmDL9vKc47QAVgr7_  \
# reviews_username
# 00dog3                        0.841779              0.041779
# 01impala                    -34.472507            -35.272507
# 02dakota                    -34.472507            -35.272507
# 02deuce                     -34.472507            -35.272507
# 0325home                   -104.545976           -105.345976
# ...                                ...                   ...
# zxcsdfd                    -104.545976           -105.345976
# zxjki                      -104.545976           -105.345976
# zyiah4                     -104.545976           -105.345976
# zzdiane                      -5.999038             -6.799038
# zzz1127                    -104.545976           -105.345976
#
# id                AV1Ymf_rglJLPUi8II2v  AV1Yn94nvKc47QAVgtst  ...  \
# reviews_username                                              ...
# 00dog3                        0.539738              0.719330  ...
# 01impala                    -34.774548            -34.594956  ...
# 02dakota                    -34.774548            -34.594956  ...
# 02deuce                     -34.774548            -34.594956  ...
# 0325home                   -104.848017           -104.668425  ...
# ...                                ...                   ...  ...
# zxcsdfd                    -104.848017           -104.668425  ...
# zxjki                      -104.848017           -104.668425  ...
# zyiah4                     -104.848017           -104.668425  ...
# zzdiane                      -6.301078             -6.121487  ...
# zzz1127                    -104.848017           -104.668425  ...
#
# id                AVpfpoUCLJeJML43BLXv  AVpfqW4WilAPnD_xf7a_  \
# reviews_username
# 00dog3                        1.029534              0.678513
# 01impala                    -34.284752            -34.635772
# 02dakota                    -34.284752            -34.635772
# 02deuce                     -34.284752            -34.635772
# 0325home                   -104.358221           -104.709242
# ...                                ...                   ...
# zxcsdfd                    -104.358221           -104.709242
# zxjki                      -104.358221           -104.709242
# zyiah4                     -104.358221           -104.709242
# zzdiane                      -5.811283             -6.162303
# zzz1127                    -104.358221           -104.709242
#
# id                AVpfr5cb1cnluZ0-pZFp  AVpfrFDZLJeJML43Bmv0  \
# reviews_username
# 00dog3                        0.837697              0.674432
# 01impala                    -34.476589            -34.639854
# 02dakota                    -34.476589            -34.639854
# 02deuce                     -34.476589            -34.639854
# 0325home                   -104.550058           -104.713323
# ...                                ...                   ...
# zxcsdfd                    -104.550058           -104.713323
# zxjki                      -104.550058           -104.713323
# zyiah4                     -104.550058           -104.713323
# zzdiane                      -6.003119             -6.166385
# zzz1127                    -104.550058           -104.713323
#
# id                AVpfrTyiLJeJML43BrSI  AVpfrfHF1cnluZ0-pRai  \
# reviews_username
# 00dog3                        0.666268              0.890758
# 01impala                    -34.648017            -34.423527
# 02dakota                    -34.648017            -34.423527
# 02deuce                     -34.648017            -34.423527
# 0325home                   -104.721487           -104.496997
# ...                                ...                   ...
# zxcsdfd                    -104.721487           -104.496997
# zxjki                      -104.721487           -104.496997
# zyiah4                     -104.721487           -104.496997
# zzdiane                      -6.174548             -5.950058
# zzz1127                    -104.721487           -104.496997
#
# id                AVpfrgjFLJeJML43BvCc  AVpfthSailAPnD_xg3ON  \
# reviews_username
# 00dog3                        0.984636              0.976473
# 01impala                    -34.329650            -34.337813
# 02dakota                    -34.329650            -34.337813
# 02deuce                     -34.329650            -34.337813
# 0325home                   -104.403119           -104.411283
# ...                                ...                   ...
# zxcsdfd                    -104.403119           -104.411283
# zxjki                      -104.403119           -104.411283
# zyiah4                     -104.403119           -104.411283
# zzdiane                      -5.856181             -5.864344
# zzz1127                    -104.403119           -104.411283
#
# id                AVpftikC1cnluZ0-p31V  AVpfvieo1cnluZ0-qdnu
# reviews_username
# 00dog3                       -1.978630              0.890758
# 01impala                    -37.292915            -34.423527
# 02dakota                    -37.292915            -34.423527
# 02deuce                     -37.292915            -34.423527
# 0325home                   -107.366385           -104.496997
# ...                                ...                   ...
# zxcsdfd                    -107.366385           -104.496997
# zxjki                      -107.366385           -104.496997
# zyiah4                     -107.366385           -104.496997
# zzdiane                      -8.819446             -5.950058
# zzz1127                    -107.366385           -104.496997
#
# [17439 rows x 246 columns]

# %%
# top 10 recommendations for user 00dog3
final_ratings.loc['00dog3'].sort_values(ascending=False)[0:10]
# Out:
# id
# AVpfRxSkilAPnD_xYrzm    1.041779
# AVpfozgyilAPnD_xfe0r    1.041779
# AVpfDflP1cnluZ0-c5RJ    1.041779
# AVpe625_ilAPnD_xQ4SP    1.037697
# AVpe4-GPLJeJML43xmuY    1.037697
# AVpf0pfrilAPnD_xi6s_    1.033615
# AVpe-MCY1cnluZ0-bCv_    1.033615
# AVpe8q4T1cnluZ0-afct    1.033615
# AVpf-bS61cnluZ0-uZcq    1.033615
# AVpfF7k8ilAPnD_xUyWf    1.033615
# Name: 00dog3, dtype: float64

# %%
common = test[test.reviews_username.isin(train.reviews_username)]
common
# there are no users common in both train and test
# Out:
# Empty DataFrame
# Columns: [id, brand, categories, manufacturer, name, reviews_date, reviews_didPurchase, reviews_doRecommend, reviews_rating, reviews_text, reviews_title, reviews_userCity, reviews_userProvince, reviews_username, user_sentiment]
# Index: []

# %% [markdown]
# ## Item-Item colloborative filtering

# %%
item_pivot = train.pivot(index='reviews_username',columns='id',values='reviews_rating').fillna(0).T
item_pivot.shape
# Out:
# (246, 17439)

# %%
mean = np.nanmean(item_pivot,axis=1)
mean.shape
# Out:
# (246,)

# %%
df_subtracted = item_pivot-mean[:,None]
df_subtracted.shape
# Out:
# (246, 17439)

# %%
df_subtracted
# Out:
# reviews_username        00dog3  01impala  02dakota   02deuce  0325home  \
# id
# AV13O1A8GV-KLJ3akUyj -0.000287 -0.000287 -0.000287 -0.000287 -0.000287
# AV14LG0R-jtxr-f38QfS -0.000287 -0.000287 -0.000287 -0.000287 -0.000287
# AV16khLE-jtxr-f38VFn -0.003555 -0.003555 -0.003555 -0.003555 -0.003555
# AV1YGDqsGV-KLJ3adc-O -0.055852 -0.055852 -0.055852 -0.055852 -0.055852
# AV1YIch7GV-KLJ3addeG -0.000287 -0.000287 -0.000287 -0.000287 -0.000287
# ...                        ...       ...       ...       ...       ...
# AVpfrfHF1cnluZ0-pRai -0.002179 -0.002179 -0.002179 -0.002179 -0.002179
# AVpfrgjFLJeJML43BvCc -0.000860 -0.000860 -0.000860 -0.000860 -0.000860
# AVpfthSailAPnD_xg3ON -0.000975 -0.000975 -0.000975 -0.000975 -0.000975
# AVpftikC1cnluZ0-p31V -0.042491 -0.042491 -0.042491 -0.042491 -0.042491
# AVpfvieo1cnluZ0-qdnu -0.002179 -0.002179 -0.002179 -0.002179 -0.002179
#
# AVpfthSailAPnD_xg3ON -0.000975 -0.000975 -0.000975 -0.000975 -0.000975
# AVpftikC1cnluZ0-p31V -0.042491 -0.042491 -0.042491 -0.042491 -0.042491
# AVpfvieo1cnluZ0-qdnu -0.002179 -0.002179 -0.002179 -0.002179 -0.002179
#
# [246 rows x 17439 columns]

# %%
# Finding the cosine similarity
item_correlation = 1- pairwise_distances(df_subtracted,metric='cosine')
item_correlation
# Out:
# array([[ 1.00000000e+00, -5.73460259e-05, -2.27710946e-04, ...,
#         -1.12578939e-04, -7.33987309e-04, -1.81642774e-04],
#        [-5.73460259e-05,  1.00000000e+00, -2.27710946e-04, ...,
#         -1.12578939e-04, -7.33987309e-04, -1.81642774e-04],
#        [-2.27710946e-04, -2.27710946e-04,  1.00000000e+00, ...,
#         -4.47031092e-04, -2.91453403e-03, -7.21271389e-04],
#        ...,
#        [-1.12578939e-04, -1.12578939e-04, -4.47031092e-04, ...,
#          1.00000000e+00, -1.44092831e-03, -3.56592290e-04],
#        [-7.33987309e-04, -7.33987309e-04, -2.91453403e-03, ...,
#         -1.44092831e-03,  1.00000000e+00, -2.32489503e-03],
#        [-1.81642774e-04, -1.81642774e-04, -7.21271389e-04, ...,
#         -3.56592290e-04, -2.32489503e-03,  1.00000000e+00]])

# %%
item_predicted_rating = np.dot(df_subtracted.fillna(0).T, item_correlation)
item_predicted_rating
# Out:
# array([[ 0.00997771,  0.00997771,  0.03719983, ...,  0.01917562,
#          0.08848724,  0.03033221],
#        [ 0.00281698,  0.00281698,  0.00876581, ...,  0.00511801,
#         -0.00316496,  0.00765067],
#        [-0.00253178, -0.00253178, -0.01247316, ..., -0.00538241,
#         -0.07162514, -0.00929144],
#        ...,
#        [-0.01427711, -0.01427711, -0.05911181, ..., -0.02844028,
#         -0.22195685, -0.04649463],
#        [ 0.00522794,  0.00522794,  0.01833932, ...,  0.00985109,
#          0.0276936 ,  0.01528737],
#        [-0.00925367, -0.00925367, -0.03916459, ..., -0.0185785 ,
#         -0.15766042, -0.03058294]])

# %%
final_rating = np.multiply(item_predicted_rating, dummy_train)
final_rating
# Out:
# id                AV13O1A8GV-KLJ3akUyj  AV14LG0R-jtxr-f38QfS  \
# reviews_username
# 00dog3                        0.009978              0.009978
# 01impala                      0.002817              0.002817
# 02dakota                     -0.002532             -0.002532
# 02deuce                       0.000143              0.000143
# 0325home                     -0.014277             -0.014277
# ...                                ...                   ...
# zxcsdfd                      -0.014277             -0.014277
# zxjki                         0.000793              0.000793
# zyiah4                       -0.014277             -0.014277
# zzdiane                       0.005228              0.005228
# zzz1127                      -0.009254             -0.009254
#
# id                AV16khLE-jtxr-f38VFn  AV1YGDqsGV-KLJ3adc-O  \
# reviews_username
# 00dog3                        0.037200              0.092773
# 01impala                      0.008766             -0.011384
# 02dakota                     -0.012473             -0.089185
# 02deuce                      -0.001854             -0.050285
# 0325home                     -0.059112             -0.260029
# ...                                ...                   ...
# zxcsdfd                      -0.059112             -0.260029
# zxjki                         0.000730             -0.040821
# zyiah4                       -0.059112             -0.260029
# zzdiane                       0.018339              0.023685
# zzz1127                      -0.039165             -0.186959
#
# id                AV1YIch7GV-KLJ3addeG  AV1YlENIglJLPUi8IHsX  \
# reviews_username
# 00dog3                        0.009978              0.030982
# 01impala                      0.002817              0.007367
# 02dakota                     -0.002532             -0.010273
# 02deuce                       0.000143             -0.001453
# 0325home                     -0.014277             -0.049007
# ...                                ...                   ...
# zxcsdfd                      -0.014277             -0.049007
# zxjki                         0.000793              0.000693
# zyiah4                       -0.014277             -0.049007
# zzdiane                       0.005228              0.015318
# zzz1127                      -0.009254             -0.032440
#
# id                AV1YmBrdGV-KLJ3adewb  AV1YmDL9vKc47QAVgr7_  \
# reviews_username
# 00dog3                        0.030835              0.061824
# 01impala                      0.007322              0.008822
# 02dakota                     -0.010241             -0.030768
# 02deuce                      -0.001459             -0.010973
# 0325home                     -0.048807             -0.117704
# ...                                ...                   ...
# zxcsdfd                      -0.048807             -0.117704
# zxjki                         0.000677             -0.006157
# zyiah4                       -0.048807             -0.117704
# zzdiane                       0.015239              0.026668
# zzz1127                      -0.032313             -0.080522
#
# id                AV1Ymf_rglJLPUi8II2v  AV1Yn94nvKc47QAVgtst  ...  \
# reviews_username                                              ...
# 00dog3                        0.044197              0.036901  ...
# 01impala                      0.008396              0.007955  ...
# 02dakota                     -0.018345             -0.013667  ...
# 02deuce                      -0.004974             -0.002856  ...
# 0325home                     -0.077066             -0.061146  ...
# ...                                ...                   ...  ...
# zxcsdfd                      -0.077066             -0.061146  ...
# zxjki                        -0.001721             -0.000226  ...
# zyiah4                       -0.077066             -0.061146  ...
# zzdiane                       0.020450              0.017701  ...
# zzz1127                      -0.051951             -0.040840  ...
#
# id                AVpfpoUCLJeJML43BLXv  AVpfqW4WilAPnD_xf7a_  \
# reviews_username
# 00dog3                        0.010035              0.039303
# 01impala                      0.002874              0.008280
# 02dakota                     -0.002474             -0.014893
# 02deuce                       0.000200             -0.003306
# 0325home                     -0.014220             -0.065777
# ...                                ...                   ...
# zxcsdfd                      -0.014220             -0.065777
# zxjki                         0.000851             -0.000488
# zyiah4                       -0.014220             -0.065777
# zzdiane                       0.005285              0.018725
# zzz1127                      -0.009196             -0.044014
#
# id                AVpfr5cb1cnluZ0-pZFp  AVpfrFDZLJeJML43Bmv0  \
# reviews_username
# 00dog3                        0.031088              0.038782
# 01impala                      0.007359              0.008082
# 02dakota                     -0.010366             -0.014849
# 02deuce                      -0.001504             -0.003383
# 0325home                     -0.049287             -0.065203
# ...                                ...                   ...
# zxcsdfd                      -0.049287             -0.065203
# zxjki                         0.000652             -0.000594
# zyiah4                       -0.049287             -0.065203
# zzdiane                       0.015348              0.018419
# zzz1127                      -0.032641             -0.043666
#
# id                AVpfrTyiLJeJML43BrSI  AVpfrfHF1cnluZ0-pRai  \
# reviews_username
# 00dog3                        0.039338              0.026738
# 01impala                      0.008171              0.006564
# 02dakota                     -0.015110             -0.008505
# 02deuce                      -0.003470             -0.000970
# 0325home                     -0.066233             -0.041595
# ...                                ...                   ...
# zxcsdfd                      -0.066233             -0.041595
# zxjki                        -0.000638              0.000863
# zyiah4                       -0.066233             -0.041595
# zzdiane                       0.018664              0.013357
# zzz1127                      -0.044368             -0.027443
#
# id                AVpfrgjFLJeJML43BvCc  AVpfthSailAPnD_xg3ON  \
# reviews_username
# 00dog3                        0.016919              0.019176
# 01impala                      0.004516              0.005118
# 02dakota                     -0.004749             -0.005382
# 02deuce                      -0.000117             -0.000132
# 0325home                     -0.025094             -0.028440
# ...                                ...                   ...
# zxcsdfd                      -0.025094             -0.028440
# zxjki                         0.001010              0.001145
# zyiah4                       -0.025094             -0.028440
# zzdiane                       0.008692              0.009851
# zzz1127                      -0.016392             -0.018579
#
# id                AVpftikC1cnluZ0-p31V  AVpfvieo1cnluZ0-qdnu
# reviews_username
# 00dog3                        0.088487              0.030332
# 01impala                     -0.003165              0.007651
# 02dakota                     -0.071625             -0.009291
# 02deuce                      -0.037395             -0.000820
# 0325home                     -0.221957             -0.046495
# ...                                ...                   ...
# zxcsdfd                      -0.221957             -0.046495
# zxjki                        -0.029068              0.001240
# zyiah4                       -0.221957             -0.046495
# zzdiane                       0.027694              0.015287
# zzz1127                      -0.157660             -0.030583
#
# [17439 rows x 246 columns]

# %%
final_rating.loc['00dog3'].sort_values(ascending=False)[0:5]
# Out:
# id
# AVpfm8yiLJeJML43AYyu    0.117951
# AVpe41TqilAPnD_xQH3d    0.102767
# AVpfW8y_LJeJML437ySW    0.102699
# AVpe59io1cnluZ0-ZgDU    0.098938
# AVpf2tw1ilAPnD_xjflC    0.096663
# Name: 00dog3, dtype: float64

# %% [markdown]
# ### Evaluating item-item collaborative filtering

# %%
common = test[test.id.isin(train.id)]
common.head()
# Out:
#                          id                       brand  \
# 6140   AVpf2tw1ilAPnD_xjflC        Summit Entertainment
# 3285   AVpe5JOgilAPnD_xQPfE                  Sony Music
# 22409  AVpfOmKwLJeJML435GM7  Clear Scalp & Hair Therapy
# 2064   AVpe41TqilAPnD_xQH3d                         FOX
# 15003  AVpf3VOfilAPnD_xjpun                      Clorox
#
#                                               categories  \
# 6140   Movies & TV Shows,Instawatch Movies By VUDU,Sh...
# 3285   Movies, Music & Books,Music,Rock,Music on CD o...
# 22409  Personal Care,Hair Care,Shampoo,Featured Brand...
# 2064   Movies & TV Shows,Movies,Romance,Romantic Come...
# 15003  Household Essentials,Cleaning Supplies,Kitchen...
#
#                 manufacturer  \
# 6140    Summit Entertainment
# 3285                Columbia
# 22409                  Clear
# 2064   Twentieth Century Fox
# 15003                 Clorox
#
#                                                     name  \
# 6140                    Red (special Edition) (dvdvideo)
# 3285          The Script - No Sound Without Silence (cd)
# 22409  Clear Scalp & Hair Therapy Total Care Nourishi...
# 2064        Mike Dave Need Wedding Dates (dvd + Digital)
# 15003  Clorox Disinfecting Wipes Value Pack Scented 1...
#
#                    reviews_date reviews_didPurchase reviews_doRecommend  \
# 6140   2016-04-08T00:00:00.000Z                 NaN                True
# 3285       2014-12-27T00:00:00Z                 NaN                 NaN
# 22409  2016-10-08T00:00:00.000Z               False               False
# 2064   2017-01-06T00:00:00.000Z                 NaN                True
# 15003  2014-12-05T00:00:00.000Z               False                True
#
#        reviews_rating                                       reviews_text  \
# 6140              5.0  This movie is a great comedy with a brilliant ...
# 3285              1.0  I bought it for the 1 song hoping there were o...
# 22409             1.0  I used to have horrible dandruff. I purchased ...
# 2064              4.0  Any fan of outrages and over the top comedy wi...
# 15003             5.0  I love using clorox products!!!!! They smell g...
#
#                           reviews_title reviews_userCity reviews_userProvince  \
# 6140                        Great movie              NaN                  NaN
# 3285                       bad just bad              NaN                  NaN
# 22409  New formula disappoints big time              NaN                  NaN
# 2064       An underrated comedy gem....              NaN                  NaN
# 15003                            Clorox              NaN                  NaN
#
#       reviews_username user_sentiment
# 6140           hewhois       Positive
# 3285          george67       Negative
# 22409            lizzy       Negative
# 2064              tf99       Positive
# 15003            stack       Positive

# %%
common_df_pivot = common.pivot(index='reviews_username',columns='id',values='reviews_rating').fillna(0).T

# %%
import pandas as pd
item_correlation_df = pd.DataFrame(item_correlation)

# %%
item_correlation_df['id']=df_subtracted.index
item_correlation_df.set_index('id',inplace=True)
item_correlation_df.head()
# Out:
#                            0         1         2         3         4    \
# id
# AV13O1A8GV-KLJ3akUyj  1.000000 -0.000057 -0.000228 -0.000834 -0.000057
# AV14LG0R-jtxr-f38QfS -0.000057  1.000000 -0.000228 -0.000834 -0.000057
# AV16khLE-jtxr-f38VFn -0.000228 -0.000228  1.000000 -0.003312 -0.000228
# AV1YGDqsGV-KLJ3adc-O -0.000834 -0.000834 -0.003312  1.000000 -0.000834
# AV1YIch7GV-KLJ3addeG -0.000057 -0.000057 -0.000228 -0.000834  1.000000
#
#                            5         6         7         8         9    ...  \
# id                                                                      ...
# AV13O1A8GV-KLJ3akUyj -0.000189 -0.000188 -0.000424 -0.000287 -0.000232  ...
# AV14LG0R-jtxr-f38QfS -0.000189 -0.000188 -0.000424 -0.000287 -0.000232  ...
# AV16khLE-jtxr-f38VFn -0.000751 -0.000748 -0.001685 -0.001138 -0.000920  ...
# AV1YGDqsGV-KLJ3adc-O -0.002751 -0.002739 -0.006174 -0.004170 -0.003372  ...
# AV1YIch7GV-KLJ3addeG -0.000189 -0.000188 -0.000424 -0.000287 -0.000232  ...
#
#                            236       237       238       239       240  \
# id
# AV13O1A8GV-KLJ3akUyj -0.000057 -0.000248 -0.000190 -0.000246 -0.000250
# AV14LG0R-jtxr-f38QfS -0.000057 -0.000248 -0.000190 -0.000246 -0.000250
# AV16khLE-jtxr-f38VFn -0.000228 -0.000987 -0.000755 -0.000976 -0.000991
# AV1YGDqsGV-KLJ3adc-O -0.000834 -0.003614 -0.002764 -0.003576 -0.003631
# AV1YIch7GV-KLJ3addeG -0.000057 -0.000248 -0.000190 -0.000246 -0.000250
#
#                            241       242       243       244       245
# id
# AV13O1A8GV-KLJ3akUyj -0.000162 -0.000099 -0.000113 -0.000734 -0.000182
# AV14LG0R-jtxr-f38QfS -0.000162 -0.000099 -0.000113 -0.000734 -0.000182
# AV16khLE-jtxr-f38VFn -0.000642 -0.000394 -0.000447 -0.002915 -0.000721
# AV14LG0R-jtxr-f38QfS             -0.000190             -0.000246
# AV16khLE-jtxr-f38VFn             -0.000755             -0.000976
# AV1YGDqsGV-KLJ3adc-O             -0.002764             -0.003576
# AV1YIch7GV-KLJ3addeG             -0.000190             -0.000246
#
# id                    AVpfrTyiLJeJML43BrSI  AVpfrfHF1cnluZ0-pRai  \
# id
# AV13O1A8GV-KLJ3akUyj             -0.000250             -0.000162
# AV14LG0R-jtxr-f38QfS             -0.000250             -0.000162
# AV16khLE-jtxr-f38VFn             -0.000991             -0.000642
# AV1YGDqsGV-KLJ3adc-O             -0.003631             -0.002350
# AV1YIch7GV-KLJ3addeG             -0.000250             -0.000162
#
# id                    AVpfrgjFLJeJML43BvCc  AVpfthSailAPnD_xg3ON  \
# id
# AV13O1A8GV-KLJ3akUyj             -0.000099             -0.000113
# AV14LG0R-jtxr-f38QfS             -0.000099             -0.000113
# AV16khLE-jtxr-f38VFn             -0.000394             -0.000447
# AV1YGDqsGV-KLJ3adc-O             -0.001445             -0.001638
# AV1YIch7GV-KLJ3addeG             -0.000099             -0.000113
#
# id                    AVpftikC1cnluZ0-p31V  AVpfvieo1cnluZ0-qdnu
# id
# AV13O1A8GV-KLJ3akUyj             -0.000734             -0.000182
# AV14LG0R-jtxr-f38QfS             -0.000734             -0.000182
# AV16khLE-jtxr-f38VFn             -0.002915             -0.000721
# AV1YGDqsGV-KLJ3adc-O             -0.010676             -0.002642
# AV1YIch7GV-KLJ3addeG             -0.000734             -0.000182
#
# [5 rows x 246 columns]

# %%
item_correlation_1=item_correlation_df[item_correlation_df.columns.isin(common.id)]

# %%
item_correlation_2=item_correlation_1.T[item_correlation_1.T.index.isin(common.id)]

# %%
item_correlation_3=item_correlation_2.T

# %%
common_item_predicted_ratings = np.dot(item_correlation_3,common_df_pivot)

# %%
dummy_test = common.copy()
dummy_test['reviews_rating'] = dummy_test['reviews_rating'].apply(lambda x: 1 if x>=1 else 0)

dummy_test = dummy_test.pivot_table(index='reviews_username', columns='id', values='reviews_rating').T.fillna(0)

common_item_predicted_ratings = np.multiply(common_item_predicted_ratings,dummy_test)

# %%
X= common_item_predicted_ratings.copy()

# %%
X[X<0]=0

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler(feature_range=(1, 5))
print(scaler.fit(X))
y = (scaler.transform(X))
# Out:
# MinMaxScaler(copy=True, feature_range=(1, 5))

# %%
total_non_nan = np.count_nonzero(~np.isnan(y))

# %%
rmse = (sum(sum((common_df_pivot.values - y )**2))/total_non_nan)**0.5
print(rmse)
# Out:
# 1.0002722787636782

# %%
# creating item_correlation for the entire data
df_pivot = df.pivot(
    index='reviews_username',
    columns='id',
    values='reviews_rating'
).fillna(0).T

mean = np.nanmean(df_pivot,axis=1)
df_subtracted = df_pivot-mean[:,None]
final_item_correlation = 1- pairwise_distances(df_subtracted,metric='cosine')

# %%
# dumping thr item-item correlation
with open('item_correlation.pkl','wb') as f:
    pickle.dump(final_item_correlation,f)

# %% [markdown]
# Since the user-user correlation is more sparse thana item-item correlation, i.e most of the users have not rated and have each user has rated only once it is better to choose item-item correlation matrix.
